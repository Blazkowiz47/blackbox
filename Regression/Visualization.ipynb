# %%
import numpy as np
import matplotlib.pyplot as plt
from utils.activation import visualization_helper

# %%
visualization_helper(-10,10,"relu")
visualization_helper(-10,10,"tanh")
visualization_helper(-10,10,"linear")
visualization_helper(-10,10,"sigmoid")
